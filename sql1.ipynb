# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandrovW/DS/blob/main/sql1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import pandas as pd
import datetime
import numpy as np
from random import randint

con = sqlite3.connect("test_1535555189.db")
cur = con.cursor()

# %%
Users = pd.DataFrame({
    'NAME': ['ИВАН', 'МАКСИМ', 'АЛЕКСАНДРА', 'МАРИЯ', 'АЛИНА', 'ВАЛЕРИЙ', 'СЕРГЕЙ'],
    'Ball': [94000.00, 138000.33, 192003.22, 57800, 40000, 100000, 100000],
    'ID_DEP': [1,3,3,4,4,3,3],
})
Users.to_sql("Users", con=con, if_exists="append", index=False)
# Out:
# 7

# %%
pd.read_sql('''
SELECT * FROM Users;
''', con)
# Out:
#          NAME       Ball  ID_DEP
# 0        ИВАН   94000.00       1
# 1      МАКСИМ  138000.33       3
# 2  АЛЕКСАНДРА  192003.22       3
# 3       МАРИЯ   57800.00       4
# 4       АЛИНА   40000.00       4
# 5     ВАЛЕРИЙ  100000.00       3
# 6      СЕРГЕЙ  100000.00       3

# %%
#Итог должен получиться такой:
# Out:
#       NAME      Ball  ID_DEP
# 0     ИВАН   94000.0       1
# 1  ВАЛЕРИЙ  100000.0       3
# 2   СЕРГЕЙ  100000.0       3
# 3    АЛИНА   40000.0       4
